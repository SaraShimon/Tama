# %%
import pandas as pd
import seaborn as snc
import matplotlib.pyplot as plt

# %%
tama_df = pd.read_csv('engineered_tama.csv')

# %%
corr = tama_df.corr()
plt.subplots(figsize=(20,15))
snc.heatmap(corr, annot=True)
# Out:
# /var/folders/9d/pylsgxd55jj55h_1svvmnmjm0000gn/T/ipykernel_31873/3296368341.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = tama_df.corr()
# <Axes: >

# %%
tama_df.columns

# %%
tama_df['ShnatBakasha'].min()

# %%
tama_df['ShnatBakasha'] - tama_df['ShnatBakasha'] - 2005
tama_df['ShnatHryter'] - tama_df['ShnatHryter'] - 2005
orr = tama_df.corr()
plt.subplots(figsize=(20,15))
snc.heatmap(corr, annot=True)

# %%
chosen_features = ['latitude', 'longitude', 'years_to_be_approved']
corr = tama_df[chosen_features].corr()
snc.heatmap(corr, annot=True)

# %%
tama_df['ShnatBakasha'] - tama_df['ShnatBakasha'] - 2005
tama_df['ShnatHryter'] - tama_df['ShnatHryter'] - 2005
orr = tama_df.corr()
plt.subplots(figsize=(20,15))
snc.heatmap(corr, annot=True)
# Out:
# /var/folders/9d/pylsgxd55jj55h_1svvmnmjm0000gn/T/ipykernel_31873/2643107586.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   orr = tama_df.corr()
# <Axes: >

# %%
chosen_features = ['latitude', 'longitude', 'years_to_be_approved']
corr = tama_df[chosen_features].corr()
snc.heatmap(corr, annot=True)
# Out:
# <Axes: >
